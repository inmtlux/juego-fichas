# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'c:\\Users\\Usuario\\Downloads\\colores'

# %%
imagen = cv2.imread('juego.jpg')
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
plt.imshow(imagen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Usuario\Documents\juego-fichas\juego.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> imagen = cv2.imread('juego.jpg')
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(imagen)
#
# NameError: name 'cv2' is not defined

# %%
imagen_2 = cv2.imread('cara-jeugo.png')
imagen_2 = cv2.cvtColor(imagen_2,cv2.COLOR_BGR2RGB)
plt.imshow(imagen_2)

# %%
metodo = cv2.TM_CCOEFF
resultado = cv2.matchTemplate(imagen,imagen_2,metodo)
plt.imshow(resultado)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Usuario\Documents\juego-fichas\juego.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> metodo = cv2.TM_CCOEFF
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> resultado = cv2.matchTemplate(imagen,imagen_2,metodo)
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(resultado)
#
# NameError: name 'cv2' is not defined

# %%
valor_min, valor_max, pos_min, pos_max = cv2.minMaxLoc(resultado)

# %%
imagen_2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Usuario\Documents\juego-fichas\juego.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Documents/juego-fichas/juego.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> coincidencias = np.where(resultado >= threshold)
#
# NameError: name 'np' is not defined

# %%
alto,ancho,colores = imagen_2.shape

# %%
top_izquierda = pos_max
botton_derecha = (pos_max[0]+ancho, pos_max[1]+alto)

# %%
cv2.rectangle(imagen, top_izquierda, botton_derecha,(255,0,0),8)
plt.imshow(imagen)
